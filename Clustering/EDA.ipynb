# %% [markdown]
# <a href="https://colab.research.google.com/github/jahnavinssdasari/Machine-Learning-Projects/blob/main/EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **TELCO CUSTOMER CHURN SERVICES EDA**

# %%
# Data Wrangling
import pandas as pd
import numpy as np

# %%
# Data Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Fetching the dataset
df = pd.read_csv("/content/drive/MyDrive/Retail_Business/telechurn_dataset.csv")

# %%
df.head()
# Out:
#   Customer ID  Count Quarter Referred a Friend  Number of Referrals  \
# 0  8779-QRDMV      1      Q3                No                    0
# 1  7495-OOKFY      1      Q3               Yes                    1
# 2  1658-BYGOY      1      Q3                No                    0
# 3  4598-XLKNJ      1      Q3               Yes                    1
# 4  4846-WHAFZ      1      Q3               Yes                    1
#
#    Tenure in Months    Offer Phone Service  Avg Monthly Long Distance Charges  \
# 0                 1      NaN            No                               0.00
# 1                 8  Offer E           Yes                              48.85
# 2                18  Offer D           Yes                              11.33
# 3                25  Offer C           Yes                              19.76
# 4                37  Offer C           Yes                               6.33
#
#   Multiple Lines  ... Unlimited Data        Contract  Paperless Billing  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 30 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Customer ID                        7043 non-null   object
#  1   Count                              7043 non-null   int64
#  2   Quarter                            7043 non-null   object
#  3   Referred a Friend                  7043 non-null   object
#  4   Number of Referrals                7043 non-null   int64
#  5   Tenure in Months                   7043 non-null   int64
#  6   Offer                              3166 non-null   object
#  7   Phone Service                      7043 non-null   object
#  8   Avg Monthly Long Distance Charges  7043 non-null   float64
#  9   Multiple Lines                     7043 non-null   object
#  10  Internet Service                   7043 non-null   object
# ...

# %%
df.describe()
# Out:
#         Count  Number of Referrals  Tenure in Months  \
# count  7043.0          7043.000000       7043.000000
# mean      1.0             1.951867         32.386767
# std       0.0             3.001199         24.542061
# min       1.0             0.000000          1.000000
# 25%       1.0             0.000000          9.000000
# 50%       1.0             0.000000         29.000000
# 75%       1.0             3.000000         55.000000
# max       1.0            11.000000         72.000000
#
#        Avg Monthly Long Distance Charges  Avg Monthly GB Download  \
# count                        7043.000000              7043.000000
# mean                           22.958954                20.515405
# std                            15.448113                20.418940
# min                             0.000000                 0.000000
# 25%                             9.210000                 3.000000
# 50%                            22.890000                17.000000
# ...

# %% [markdown]
# Mean, Median, Mode of Numerical Columns

# %%
numeric_df = df.select_dtypes(include=[np.number])

# Mean
mean_values = numeric_df.mean()

# Median
median_values = numeric_df.median()

# Mode
mode_values = numeric_df.mode().iloc[0]

print(f"Mean:\n{mean_values}\n")
print(f"Median:\n{median_values}\n")
print(f"Mode:\n{mode_values}\n")
# Out:
# Mean:
# Count                                   1.000000
# Number of Referrals                     1.951867
# Tenure in Months                       32.386767
# Avg Monthly Long Distance Charges      22.958954
# Avg Monthly GB Download                20.515405
# Monthly Charge                         64.761692
# Total Charges                        2280.381264
# Total Refunds                           1.962182
# Total Extra Data Charges                6.860713
# Total Long Distance Charges           749.099262
# Total Revenue                        3034.379056
# Offer_encoded                           3.700838
# Internet Type_encoded                   1.746415
# Referred a Friend_encoded               0.457476
# Phone Service_encoded                   0.903166
# Multiple Lines_encoded                  0.421837
# Internet Service_encoded                0.783331
# dtype: float64
#
# Median:
# Count                                   1.00
# Number of Referrals                     0.00
# ...

# %% [markdown]
# Skweness and Kurtosis of Numeric columns

# %%
skewness = numeric_df.skew()

kurtosis = numeric_df.kurtosis()

print(f"Skewness:\n{skewness}\n")
print(f"Kurtosis:\n{kurtosis}\n")
# Out:
# Skewness:
# Count                                0.000000
# Number of Referrals                  1.446060
# Tenure in Months                     0.240543
# Avg Monthly Long Distance Charges    0.049176
# Avg Monthly GB Download              1.216584
# Monthly Charge                      -0.220524
# Total Charges                        0.963791
# Total Refunds                        4.328517
# Total Extra Data Charges             4.091209
# Total Long Distance Charges          1.238282
# Total Revenue                        0.919410
# dtype: float64
#
# Kurtosis:
# Count                                 0.000000
# Number of Referrals                   0.721964
# Tenure in Months                     -1.387052
# Avg Monthly Long Distance Charges    -1.254654
# Avg Monthly GB Download               0.881502
# Monthly Charge                       -1.257260
# Total Charges                        -0.227693
# Total Refunds                        18.350658
# ...

# %% [markdown]
# Histogram Plot

# %%
df_cleaned.hist(figsize=(12, 8), bins=20)
plt.tight_layout()
plt.show()

# %%
#Count plot
sns.countplot(x='Referred a Friend', hue='Number of Referrals', data=df)
plt.title('Referred a Friend vs Number of Referrals')
plt.show()

# %% [markdown]
# Customers who referred a friend were more likely to have a higher number of referrals, which may suggest customer satisfaction.

# %%
# Boxplot - Total Revenue by Referral Status
sns.boxplot(x='Referred a Friend', y='Total Revenue', data=df)
plt.title('Total Revenue by Referral Status')
plt.show()

# %% [markdown]
# *   Customers who referred a friend tended to generate higher revenues, likely due
# to increased satisfaction and longer tenure with the service.
# *   There is a significant range of revenue even within customers who didn’t refer a friend, indicating other factors also affect total revenue.

# %%
#Scatter Plot - Customer Tenure vs Total Revenue
sns.scatterplot(x='Tenure in Months', y='Total Revenue', data=df)
plt.title('Customer Tenure vs Total Revenue')
plt.show()

# %% [markdown]
# From this observation we can say that, customers with longer tenures generally contribute more to total revenue

# %%
#Box Plot - Offer Type vs Total Revenue
sns.boxplot(x='Offer', y='Total Revenue', data=df)
plt.title('Offer Type vs Total Revenue')
plt.show()

# %% [markdown]
# * Certain offer types (e.g., Offer C and D) seem to generate higher revenues, while others have a more varied impact on revenue.
# * Offer A seems to have a broader distribution, with some customers generating significant revenue, possibly depending on additional factors like tenure or services used.

# %% [markdown]
# ---
#
# Correlation Matrix

# %%
numeric_df_cleaned = df_cleaned.select_dtypes(include=[np.number])

numeric_df_cleaned = numeric_df_cleaned.dropna()

# correlation matrix
correlation_matrix = numeric_df_cleaned.corr()

# Plotting the Correlation Matrix
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix of Cleaned Data')
plt.show()

# %% [markdown]
# We can see that, strong positive correlation between Total Charges and Tenure (longer tenure often results in higher total charges).
#
# Weak correlations between other features such as Monthly Charges and Tenure, suggesting that monthly charges remain relatively consistent across different tenure ranges

# %% [markdown]
# ---
#
#
#
# *   Checking missing values.
# *   Treatment for missing values.

# %%
missing_values = df.isnull().sum()
print(f"Missing values per column:\n{missing_values}")

df_filled = df.fillna(df.median(numeric_only=True))

print(f"Missing values after treatment:\n{df_filled.isnull().sum()}")
# Out:
# Missing values per column:
# Customer ID                             0
# Count                                   0
# Quarter                                 0
# Referred a Friend                       0
# Number of Referrals                     0
# Tenure in Months                        0
# Offer                                3877
# Phone Service                           0
# Avg Monthly Long Distance Charges       0
# Multiple Lines                          0
# Internet Service                        0
# Internet Type                        1526
# Avg Monthly GB Download                 0
# Online Security                         0
# Online Backup                           0
# Device Protection Plan                  0
# Premium Tech Support                    0
# Streaming TV                            0
# Streaming Movies                        0
# Streaming Music                         0
# Unlimited Data                          0
# Contract                                0
# ...

# %%
df_cleaned = df.dropna(subset=['Offer', 'Internet Type'])

print(f"Missing values after dropping rows with missing categorical data:\n{df_cleaned.isnull().sum()}")
# Out:
# Missing values after dropping rows with missing categorical data:
# Customer ID                          0
# Count                                0
# Quarter                              0
# Referred a Friend                    0
# Number of Referrals                  0
# Tenure in Months                     0
# Offer                                0
# Phone Service                        0
# Avg Monthly Long Distance Charges    0
# Multiple Lines                       0
# Internet Service                     0
# Internet Type                        0
# Avg Monthly GB Download              0
# Online Security                      0
# Online Backup                        0
# Device Protection Plan               0
# Premium Tech Support                 0
# Streaming TV                         0
# Streaming Movies                     0
# Streaming Music                      0
# Unlimited Data                       0
# Contract                             0
# ...

# %% [markdown]
# Check duplicates

# %%
duplicates = df.duplicated().sum()
print(f"Number of duplicate rows: {duplicates}")
# Out:
# Number of duplicate rows: 0

# %% [markdown]
# Variance

# %%
variance = numeric_df.var()
print(f"Variance:\n{variance}")
# Out:
# Variance:
# Count                                0.000000e+00
# Number of Referrals                  9.007197e+00
# Tenure in Months                     6.023128e+02
# Avg Monthly Long Distance Charges    2.386442e+02
# Avg Monthly GB Download              4.169331e+02
# Monthly Charge                       9.054109e+02
# Total Charges                        5.135755e+06
# Total Refunds                        6.245131e+01
# Total Extra Data Charges             6.302599e+02
# Total Long Distance Charges          7.168332e+05
# Total Revenue                        8.209397e+06
# dtype: float64

# %% [markdown]
# Treatment for outliers

# %%
# Using IQR to detect outliers
Q1 = numeric_df.quantile(0.25)
Q3 = numeric_df.quantile(0.75)
IQR = Q3 - Q1

# Filter out the outliers
df_no_outliers = numeric_df[~((numeric_df < (Q1 - 1.5 * IQR)) | (numeric_df > (Q3 + 1.5 * IQR))).any(axis=1)]

print(f"Number of rows after outlier removal: {df_no_outliers.shape[0]}")
# Out:
# Number of rows after outlier removal: 4898

# %% [markdown]
# Label encoding

# %%
from sklearn.preprocessing import LabelEncoder

# List of nominal columns
nominal_columns = ['Offer', 'Internet Type', 'Referred a Friend', 'Phone Service', 'Multiple Lines', 'Internet Service']

# label encoding to all nominal columns
le = LabelEncoder()

for col in nominal_columns:
    df[col + '_encoded'] = le.fit_transform(df[col].astype(str))

# Display the encoded columns
print(df[['Offer', 'Offer_encoded', 'Internet Type', 'Internet Type_encoded']].head())
# Out:
#      Offer  Offer_encoded Internet Type  Internet Type_encoded
# 0      NaN              5           DSL                      1
# 1  Offer E              4   Fiber Optic                      2
# 2  Offer D              3   Fiber Optic                      2
# 3  Offer C              2   Fiber Optic                      2
# 4  Offer C              2   Fiber Optic                      2

# %%
# Drop original nominal columns after encoding
df_cleaned = df.drop(columns=nominal_columns)
